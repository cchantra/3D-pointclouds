# %%
import pandas as pd
import numpy as np
import json

# %%
file_path = 'csv/palm_pcd_prop.csv'
file_path2 = 'csv/coconut_pcd_prop.csv'

# %%
df1 = pd.read_csv(file_path, delimiter='#')

# %%
df1.head()
# Out:
#         name                               points  \
# p1.ply    953  [4.63392369 5.35084545 2.93490266]
# p2.ply   1373  [4.11424497 4.10224762 2.00170534]
# p3.ply   2067  [5.27256142 6.15045178 2.26578126]
# p4.ply   2007  [5.55810574 4.65292764 2.83986891]
# p5.ply   1272  [5.19255253 4.92706971 1.09265762]
#
#                                     aabb_max   \
# p1.ply  [-3.99559292 -5.26512135 -4.99509765]
# p2.ply  [-3.59245059 -4.4050766  -5.92829497]
# p3.ply  [-5.58974326 -4.44403064 -3.74422088]
# p4.ply  [-4.78955051 -4.12685751 -3.65012896]
# p5.ply  [-4.51884273 -4.51360412 -2.50734467]
#
#                                  aabb_min   \
# p1.ply  [6.6957695  6.60703175 6.43031642]
# p2.ply  [7.12264526 5.47803726 5.43651884]
# p3.ply  [7.77256012 8.26043892 4.48929602]
# p4.ply  [7.46155963 7.30044759 3.59029227]
# p5.ply  [7.31826308 8.10239989 2.1464591 ]
#
#                                      obb_max     obb_min      abb_vol  \
# p1.ply  [-7.74950337 -8.60234116 -8.91357619]  726.472575  723.418897
# p2.ply  [-5.91190051 -6.54232507 -8.19517336]  519.917447  521.378838
# p3.ply  [-9.32513801 -8.21885208 -5.20291485]  691.634027  748.730508
# p4.ply  [-7.02099307 -6.58766281 -4.00185846]  589.617596  703.681214
# p5.ply  [-6.84361628 -6.29880026 -3.36578998]  330.055824  305.674331
#
#                                                  obb_vol    center   \
# p1.ply  [-4.44650337e-11 -8.77085006e-11 -4.41386463e-15]         2
# p2.ply  [ 3.76463240e-11  6.52875439e-11 -1.55253329e-15]         2
# p3.ply  [-1.93743932e-11 -6.83735852e-11 -1.16876889e-16]         2
# p4.ply  [-7.83062703e-12 -1.91415327e-11 -5.66451608e-16]         2
# p5.ply  [ 1.53756085e-11 -7.61458709e-11  3.12817557e-15]         2
#
#          voxel_grid                                           avg_dist   \
# p1.ply      0.269738   TriangleMesh with 953 points and 1222 triangles.
# p2.ply      0.214846  TriangleMesh with 1373 points and 1027 triangles.
# p3.ply      0.234772  TriangleMesh with 2067 points and 1339 triangles.
# p4.ply      0.228189  TriangleMesh with 2007 points and 2024 triangles.
# p5.ply      0.195804  TriangleMesh with 1272 points and 1190 triangles.
#
#                                                 bpa_mesh     poison_mesh   \
# p1.ply  TriangleMesh with 4135 points and 8114 triangles.        4.209262
# p2.ply  TriangleMesh with 4090 points and 7942 triangles.        4.456697
# p3.ply  TriangleMesh with 6339 points and 12490 triang...        4.775218
# p4.ply  TriangleMesh with 5638 points and 11060 triang...        4.755777
# p5.ply  TriangleMesh with 3835 points and 7510 triangles.        4.746226
#
#                                   poison_avg_density    \
# p1.ply   TriangleMesh with 44 points and 84 triangles.
# p2.ply  TriangleMesh with 78 points and 152 triangles.
# p3.ply  TriangleMesh with 64 points and 124 triangles.
# p4.ply  TriangleMesh with 58 points and 112 triangles.
# p5.ply  TriangleMesh with 58 points and 112 triangles.
#
#                                              convex_hull    convex_hull_pts
# p1.ply  [98, 546, 466, 788, 878, 353, 459, 728, 706, 4...                 NaN
# p2.ply  [1267, 1048, 1032, 985, 208, 1030, 1022, 136, ...                 NaN
# p3.ply  [1963, 653, 1985, 1078, 358, 1987, 10, 555, 67...                 NaN
# p4.ply  [180, 1956, 717, 2005, 2006, 1309, 437, 813, 1...                 NaN
# p5.ply  [158, 683, 1271, 115, 1226, 1240, 645, 36, 803...                 NaN

# %%
df1.keys()
# Out:
# Index(['name ', ' points', ' aabb_max ', ' aabb_min ', ' obb_max ',
#        ' obb_min ', ' abb_vol', ' obb_vol ', ' center ', ' voxel_grid ',
#        ' avg_dist ', ' bpa_mesh ', '  poison_mesh ', ' poison_avg_density  ',
#        ' convex_hull ', ' convex_hull_pts  '],
#       dtype='object')

# %%
df1[' aabb_max '][0].split()
# Out:
# ['[-3.99559292', '-5.26512135', '-4.99509765]']

# %%
df2 = pd.read_csv(file_path2, delimiter='#')
df2.head()
# Out:
#              name                               points  \
# row2-11.ply  19332  [3.4452412  3.52545291 3.06002595]
# row2-12.ply  13468  [3.14737607 2.55581243 2.60404464]
# row2-13.ply  11663  [2.14730926 2.49684838 2.4399922 ]
# row2-14.ply  11663  [2.46872918 2.27505012 2.53365703]
# row2-15.ply  11962  [3.36570428 2.96924934 2.45078428]
#
#                                          aabb_max   \
# row2-11.ply  [-3.01874806 -3.20854825 -1.47397445]
# row2-12.ply  [-2.53261661 -2.65018694 -1.80995539]
# row2-13.ply  [-1.91769318 -2.76314994 -1.71700787]
# row2-14.ply  [-1.9043177  -2.70294862 -1.7723432 ]
# row2-15.ply  [-2.31929328 -2.80175056 -2.09821599]
#
#                                       aabb_min   \
# row2-11.ply  [6.11727214 5.23033884 3.54811947]
# row2-12.ply  [4.42786511 4.51689137 3.18886943]
# row2-13.ply  [3.11809578 2.74801088 3.36916531]
# row2-14.ply  [4.70502142 4.45441422 4.05747797]
# row2-15.ply  [5.43107924 4.96026176 4.03520561]
#
#                                           obb_max     obb_min      abb_vol  \
# row2-11.ply  [-5.28906098 -5.8311525  -2.35081412]  197.358287  287.706124
# row2-12.ply  [-5.14232544 -4.93666604 -2.91400234]  130.522150  200.829781
# row2-13.ply  [-3.49997937 -2.89061744 -2.81054106]   88.884585  101.246890
# row2-14.ply  [-4.47988043 -4.42543427 -5.28821742]   93.737413  169.316074
# row2-15.ply  [-4.17968214 -5.05244741 -3.81033546]  149.244148  172.764381
#
#                                                       obb_vol    center   \
# row2-11.ply  [-4.58429074e-14  8.44936462e-15 -5.98666173e-15]         2
# row2-12.ply  [-4.63450434e-14 -1.66813730e-14 -6.08113368e-15]         2
# row2-13.ply  [-2.00929520e-14 -2.62005399e-14 -5.32465361e-16]         2
# row2-14.ply  [ 1.01289693e-14 -4.60765306e-14  3.94480908e-15]         2
# row2-15.ply  [-6.38316055e-15  9.21353317e-15  2.88960555e-15]         2
#
#               voxel_grid                                           avg_dist   \
# row2-11.ply      0.046480  TriangleMesh with 19332 points and 5021 triang...
# row2-12.ply      0.049551  TriangleMesh with 13468 points and 4242 triang...
# row2-13.ply      0.049766  TriangleMesh with 11663 points and 2615 triang...
# row2-14.ply      0.047716  TriangleMesh with 11663 points and 2906 triang...
# row2-15.ply      0.047252  TriangleMesh with 11962 points and 3195 triang...
#
#                                                      bpa_mesh   \
# row2-11.ply  TriangleMesh with 78853 points and 157720 tria...
# row2-12.ply  TriangleMesh with 56311 points and 112818 tria...
# row2-13.ply  TriangleMesh with 52042 points and 104454 tria...
# row2-14.ply  TriangleMesh with 47282 points and 94613 trian...
# row2-15.ply  TriangleMesh with 44442 points and 89028 trian...
#
#                poison_mesh                              poison_avg_density    \
# row2-11.ply        6.231523  TriangleMesh with 111 points and 218 triangles.
# row2-12.ply        5.789658  TriangleMesh with 142 points and 280 triangles.
# row2-13.ply        5.728795  TriangleMesh with 107 points and 210 triangles.
# row2-14.ply        5.672143  TriangleMesh with 121 points and 238 triangles.
# row2-15.ply        5.931062  TriangleMesh with 139 points and 274 triangles.
#
#                                                   convex_hull   \
# row2-11.ply  [353, 17857, 6526, 14629, 18994, 12823, 1772, ...
# row2-12.ply  [6747, 2741, 765, 11076, 4389, 5387, 11178, 12...
# row2-13.ply  [8352, 794, 8625, 0, 11286, 10620, 258, 3581, ...
# row2-14.ply  [3118, 7828, 3063, 7130, 7801, 8842, 6274, 984...
# row2-15.ply  [6281, 7548, 11705, 441, 8870, 3581, 8845, 716...
#
#               convex_hull_pts
# row2-11.ply                 NaN
# row2-12.ply                 NaN
# row2-13.ply                 NaN
# row2-14.ply                 NaN
# row2-15.ply                 NaN

# %%
file_path = 'csv/coconut_40.csv'
file_path2 = 'csv/palm_40.csv'

# %%
df1 = pd.read_csv(file_path, )
df2 = pd.read_csv(file_path2, )

# %%
df1 = pd.read_csv(file_path, )
df2 = pd.read_csv(file_path2, )
df1 =df1.drop(columns = ['name'])
df1.pop(df1.columns[0])
df1= df1.loc[:,df1.notna().all(axis=0)]
df2 =df2.drop(columns = ['name'])
df2.pop(df2.columns[0])
df2= df2.loc[:,df2.notna().all(axis=0)]

 
df1['type'] = 0
df2['type'] = 1
df3 = pd.concat([df1, df2], ignore_index=True)
df3= df3.loc[:,df3.notna().all(axis=0)]

X = df3.loc[:, df3.columns != "type"]
y = df3['type']

# %%
def evaluate_model(model, x_test, y_test):
    from sklearn import metrics

    # Predict Test Data 
    y_pred = model.predict(x_test)

    # Calculate accuracy, precision, recall, f1-score, and kappa score
    acc = metrics.accuracy_score(y_test, y_pred)
    prec = metrics.precision_score(y_test, y_pred)
    rec = metrics.recall_score(y_test, y_pred)
    f1 = metrics.f1_score(y_test, y_pred)
    kappa = metrics.cohen_kappa_score(y_test, y_pred)

    # Calculate area under curve (AUC)
    y_pred_proba = model.predict_proba(x_test)[::,1]
    fpr, tpr, _ = metrics.roc_curve(y_test, y_pred_proba)
    auc = metrics.roc_auc_score(y_test, y_pred_proba)

    # Display confussion matrix
    cm = metrics.confusion_matrix(y_test, y_pred)

    return {'acc': acc, 'prec': prec, 'rec': rec, 'f1': f1, 'kappa': kappa, 
            'fpr': fpr, 'tpr': tpr, 'auc': auc, 'cm': cm}

# %%
from sklearn.model_selection import train_test_split
target = df3['type']
X_train, X_test, y_train, y_test = train_test_split(df3 , target, 
                                                    shuffle = True, 
                                                    test_size=0.2, 
                                                    random_state=1)

# %% [markdown]
# https://medium.com/analytics-vidhya/building-classification-model-with-python-9bdfc13faa4b

# %%
from sklearn import tree 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier 
from sklearn.naive_bayes import GaussianNB

# Building Decision Tree model 
dtc = tree.DecisionTreeClassifier(random_state=0)
dtc.fit(X_train, y_train)
rf = RandomForestClassifier(random_state=0)
rf.fit(X_train, y_train)

knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(X_train, y_train)

nb = GaussianNB()
nb.fit(X_train, y_train)

# Evaluate Model
dtc_eval = evaluate_model(dtc, X_test, y_test)
rf_eval = evaluate_model(rfc, X_test, y_test)
knn_eval = evaluate_model(knn, X_test, y_test)
nb_eval = evaluate_model(knn, X_test, y_test)

models = [ {'tree': dtc}, {'randomforest': rf}, {'knn': knn}, {'naive bayes':
                                                               nb}]

# Print result
print('Accuracy:', dtc_eval['acc'])
print('Precision:', dtc_eval['prec'])
print('Recall:', dtc_eval['rec'])
print('F1 Score:', dtc_eval['f1'])
print('Cohens Kappa Score:', dtc_eval['kappa'])
print('Area Under Curve:', dtc_eval['auc'])
print('Confusion Matrix:\n', dtc_eval['cm'])

# Print result
print('Accuracy:', rf_eval['acc'])
print('Precision:', rf_eval['prec'])
print('Recall:', rf_eval['rec'])
print('F1 Score:', rf_eval['f1'])
print('Cohens Kappa Score:', rfc_eval['kappa'])
print('Area Under Curve:', rf_eval['auc'])
print('Confusion Matrix:\n', rf_eval['cm'])

print('Accuracy:', knn_eval['acc'])
print('Precision:', knn_eval['prec'])
print('Recall:', knn_eval['rec'])
print('F1 Score:', knn_eval['f1'])
print('Cohens Kappa Score:', knn_eval['kappa'])
print('Area Under Curve:', knn_eval['auc'])
print('Confusion Matrix:\n', knn_eval['cm'])

print('Accuracy:', nb_eval['acc'])
print('Precision:', nb_eval['prec'])
print('Recall:',nb_eval['rec'])
print('F1 Score:', nb_eval['f1'])
print('Cohens Kappa Score:', nb_eval['kappa'])
print('Area Under Curve:', nb_eval['auc'])
print('Confusion Matrix:\n', nb_eval['cm'])
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Cohens Kappa Score: 1.0
# Area Under Curve: 1.0
# Confusion Matrix:
#  [[ 6  0]
#  [ 0 10]]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Cohens Kappa Score: 1.0
# Area Under Curve: 1.0
# Confusion Matrix:
#  [[ 6  0]
#  [ 0 10]]
# Accuracy: 0.875
# Precision: 0.9
# Recall: 0.9
# F1 Score: 0.9
# Cohens Kappa Score: 0.7333333333333334
# Area Under Curve: 0.9583333333333334
# Confusion Matrix:
#  [[5 1]
#  [1 9]]
# Accuracy: 0.875
# Precision: 0.9
# Recall: 0.9
# F1 Score: 0.9
# Cohens Kappa Score: 0.7333333333333334
# Area Under Curve: 0.9583333333333334
# Confusion Matrix:
#  [[5 1]
#  [1 9]]

# %%
# Intitialize figure with two plots
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Model Comparison', fontsize=16, fontweight='bold')
fig.set_figheight(7)
fig.set_figwidth(14)
fig.set_facecolor('white')

# First plot
## set bar size
barWidth = 0.2
dtc_score = [dtc_eval['acc'], dtc_eval['prec'], dtc_eval['rec'], dtc_eval['f1'], dtc_eval['kappa']]
rf_score = [rf_eval['acc'], rf_eval['prec'], rf_eval['rec'], rf_eval['f1'], rf_eval['kappa']]
nb_score = [nb_eval['acc'], nb_eval['prec'], nb_eval['rec'], nb_eval['f1'], nb_eval['kappa']]
knn_score = [knn_eval['acc'], knn_eval['prec'], knn_eval['rec'], knn_eval['f1'], knn_eval['kappa']]

## Set position of bar on X axis
r1 = np.arange(len(dtc_score))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]

## Make the plot
ax1.bar(r1, dtc_score, width=barWidth, edgecolor='white', label='Decision Tree')
ax1.bar(r2, rf_score, width=barWidth, edgecolor='white', label='Random Forest')
ax1.bar(r3, nb_score, width=barWidth, edgecolor='white', label='Naive Bayes')
ax1.bar(r4, knn_score, width=barWidth, edgecolor='white', label='K-Nearest Neighbors')

## Configure x and y axis
ax1.set_xlabel('Metrics', fontweight='bold')
labels = ['Accuracy', 'Precision', 'Recall', 'F1', 'Kappa']
ax1.set_xticks([r + (barWidth * 1.5) for r in range(len(dtc_score))], )
ax1.set_xticklabels(labels)
ax1.set_ylabel('Score', fontweight='bold')
ax1.set_ylim(0, 1)

## Create legend & title
ax1.set_title('Evaluation Metrics', fontsize=14, fontweight='bold')
ax1.legend()

# Second plot
## Comparing ROC Curve
ax2.plot(dtc_eval['fpr'], dtc_eval['tpr'], label='Decision Tree, auc = {:0.5f}'.format(dtc_eval['auc']))
ax2.plot(rf_eval['fpr'], rf_eval['tpr'], label='Random Forest, auc = {:0.5f}'.format(rf_eval['auc']))
ax2.plot(nb_eval['fpr'], nb_eval['tpr'], label='Naive Bayes, auc = {:0.5f}'.format(nb_eval['auc']))
ax2.plot(knn_eval['fpr'], knn_eval['tpr'], label='K-Nearest Nieghbor, auc = {:0.5f}'.format(knn_eval['auc']))

## Configure x and y axis
ax2.set_xlabel('False Positive Rate', fontweight='bold')
ax2.set_ylabel('True Positive Rate', fontweight='bold')

## Create legend & title
ax2.set_title('ROC Curve', fontsize=14, fontweight='bold')
ax2.legend(loc=4)

plt.show()

# %%
from sklearn.model_selection import cross_val_score


for items in models:
    for k,v in items.items():
        m = items[k]
        
    scores = cross_val_score(m, X, y, cv=15, scoring='accuracy')
    print(k,scores.mean())


k_range = list(range(1, 25))
k_scores = []
for k in k_range:
    knn1 = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn1, X, y, cv=10, scoring='accuracy')
    k_scores.append({k: scores.mean()})
for item in k_scores:
    for k,v in item.items():
        print('neibour' , k, 'acc',v)
# Out:
# tree 0.9488888888888888
# randomforest 0.9377777777777777
# knn 0.9733333333333334
# naive bayes 0.9888888888888889
# neibour 1 acc 0.9625
# neibour 2 acc 0.975
# neibour 3 acc 0.975
# neibour 4 acc 0.9625
# neibour 5 acc 0.975
# neibour 6 acc 0.9625
# neibour 7 acc 0.95
# neibour 8 acc 0.95
# neibour 9 acc 0.95
# neibour 10 acc 0.925
# neibour 11 acc 0.9125
# neibour 12 acc 0.9125
# neibour 13 acc 0.9125
# neibour 14 acc 0.875
# neibour 15 acc 0.875
# neibour 16 acc 0.8625
# neibour 17 acc 0.875
# neibour 18 acc 0.85
# neibour 19 acc 0.8625
# neibour 20 acc 0.8375
# neibour 21 acc 0.825
# neibour 22 acc 0.825
# neibour 23 acc 0.825
# neibour 24 acc 0.8375

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # clustering
#
# https://machinelearningmastery.com/clustering-algorithms-with-python/

# %%
df1 = pd.read_csv(file_path, )
df2 = pd.read_csv(file_path2, )
df1 =df1.drop(columns = ['name'])
df1.pop(df1.columns[0])
df1= df1.loc[:,df1.notna().all(axis=0)]
df2 =df2.drop(columns = ['name'])
df2.pop(df2.columns[0])
df2= df2.loc[:,df2.notna().all(axis=0)]

 
df1['type'] = 0
df2['type'] = 1
df3 = pd.concat([df1, df2], ignore_index=True)
df3= df3.loc[:,df3.notna().all(axis=0)]

X = df3.loc[:, df3.columns != "type"]
y = df3['type']

X =X.values
y =y.values

# %%
for class_value in range(2):
 # get row indexes for samples with this class
 row_ix = where(y == class_value)
 # create scatter of these samples
 pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot

# %%
# agglomerative clustering
from numpy import unique
from numpy import where

from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import AffinityPropagation
from sklearn.cluster import Birch
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
from sklearn.cluster import MeanShift
from sklearn.cluster import OPTICS
from sklearn.cluster import SpectralClustering
from sklearn.mixture import GaussianMixture

from matplotlib import pyplot


# define the model
modelagg = AgglomerativeClustering(n_clusters=2)
# fit model and predict clusters



modelb = Birch(threshold=0.01, n_clusters=2)
modela = AffinityPropagation(damping=0.9)
modeldb = DBSCAN(eps=0.30, min_samples=9)
modelkm = KMeans(n_clusters=2)
modelmbkm = MiniBatchKMeans(n_clusters=2)
modelmsh = MeanShift()
modeloptics = OPTICS(eps=0.8, min_samples=10)
modelsc = SpectralClustering(n_clusters=2)
modelgm = GaussianMixture(n_components=2)

models =  [ {'agglo': modelagg},
    {'birch': modelb}, {'affinity': modela}, 
    {'dbscan': modeldb}, {'kmeans': modelkm},
    {'minbatchkmeans': modelmbkm},
    {'meanshift': modelmsh},{'optics': modeloptics},
    {'spectral': modelsc}, {'gaussianmixture': modelgm},
     
]

# %%
def train_visualize(model):
    yhat = model.fit_predict(X)
    # retrieve unique clusters
    clusters = unique(yhat)
    # create scatter plot for samples from each cluster
    for cluster in clusters:
        # get row indexes for samples with this cluster
        row_ix = where(yhat == cluster)
        # create scatter of these samples
        
        pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
    # show the plot
    pyplot.show()
    return yhat

# %%
from sklearn.metrics import adjusted_rand_score 
from sklearn.metrics import rand_score 
from sklearn.metrics import silhouette_score 
from sklearn.metrics import davies_bouldin_score 
from sklearn.metrics import mutual_info_score , calinski_harabasz_score

def performance_cluster(target,features,labels_):
    ari = adjusted_rand_score(target, labels_)  
    ss = silhouette_score(features,labels_) 
    ris = rand_score(target, labels_) 
     
    mis = mutual_info_score(target, labels_) 
    dbs = davies_bouldin_score(features, labels_) 
    
    cal = calinski_harabasz_score(features, labels_)
    
    scores = {'mutual_info': mis}, {'davis_bouldin': dbs}, {'adjusted_rand_score':ari}, {'silhouette':ss},{'rand_score': ris},  {'calinski': cal},
                
    
    
    return scores

# %%
yhat_array = []
for model in models:
    k,v = list(model.items())[0]
    print(k)
    yhat = train_visualize(v)
    yhat_array.append(yhat)
# Out:
# agglo
# birch
# affinity
# /home/chantana/anaconda3/envs/tf/lib/python3.7/site-packages/sklearn/cluster/_affinity_propagation.py:154: FutureWarning: 'random_state' has been introduced in 0.23. It will be set to None starting from 1.0 (renaming of 0.25) which means that results will differ at every function call. Set 'random_state' to None to silence this warning, or to 0 to keep the behavior of versions <0.23.
#   FutureWarning
# dbscan
# kmeans
# minbatchkmeans
# meanshift
# optics
# spectral
# /home/chantana/anaconda3/envs/tf/lib/python3.7/site-packages/sklearn/manifold/_spectral_embedding.py:245: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# gaussianmixture

# %%
score_array = {}
for yhat,model in zip(yhat_array,models):
    k,v = list(model.items())[0]
    print(k)
    try: 
        score_array[k] = performance_cluster(y,X,yhat)
        print(score_array[k])
    except:
        print('cannot measure')
# Out:
# agglo
# ({'mutual_info': 0.12850178115343996}, {'davis_bouldin': 0.5923108059221817}, {'adjusted_rand_score': 0.09941925770140764}, {'silhouette': 0.6081156421364777}, {'rand_score': 0.5471518987341772}, {'calinski': 115.51473598969481})
# birch
# ({'mutual_info': 0.12850178115343996}, {'davis_bouldin': 0.5923108059221817}, {'adjusted_rand_score': 0.09941925770140764}, {'silhouette': 0.6081156421364777}, {'rand_score': 0.5471518987341772}, {'calinski': 115.51473598969481})
# affinity
# ({'mutual_info': 0.568046574675398}, {'davis_bouldin': 0.7731581775675409}, {'adjusted_rand_score': 0.307605315238903}, {'silhouette': 0.34095550732285285}, {'rand_score': 0.6566455696202531}, {'calinski': 147.43965713229665})
# dbscan
# cannot measure
# kmeans
# ({'mutual_info': 0.20223272608716186}, {'davis_bouldin': 0.6096026445410114}, {'adjusted_rand_score': 0.21845881141159842}, {'silhouette': 0.6037616135370426}, {'rand_score': 0.6079113924050633}, {'calinski': 133.92501087347864})
# minbatchkmeans
# ({'mutual_info': 0.2297073002884747}, {'davis_bouldin': 0.6205851639092677}, {'adjusted_rand_score': 0.2684542309505357}, {'silhouette': 0.5948616076899353}, {'rand_score': 0.6332278481012659}, {'calinski': 132.77506552890657})
# meanshift
# ({'mutual_info': 0.2626714305887388}, {'davis_bouldin': 0.5373009490359753}, {'adjusted_rand_score': 0.3357087317937331}, {'silhouette': 0.5192033472377627}, {'rand_score': 0.6680379746835443}, {'calinski': 127.90534151798371})
# optics
# ({'mutual_info': 0.39710092967003646}, {'davis_bouldin': 0.9526483991143215}, {'adjusted_rand_score': 0.6765330406006362}, {'silhouette': 0.33457729181375484}, {'rand_score': 0.8382911392405064}, {'calinski': 43.94917857951576})
# spectral
# ({'mutual_info': 0.0031495295627013697}, {'davis_bouldin': 6.569133775453518}, {'adjusted_rand_score': -0.005761428834350919}, {'silhouette': 0.054903621395612244}, {'rand_score': 0.49651898734177213}, {'calinski': 1.200562426941988})
# gaussianmixture
# ({'mutual_info': 0.693147180559945}, {'davis_bouldin': 1.0035995580088195}, {'adjusted_rand_score': 1.0}, {'silhouette': 0.3160736063578475}, {'rand_score': 1.0}, {'calinski': 42.01103462747964})

# %%
  
for k,score in score_array.items():
    print(score)
    print(k, score)
# Out:
# ({'mutual_info': 0.12850178115343996}, {'davis_bouldin': 0.5923108059221817}, {'adjusted_rand_score': 0.09941925770140764}, {'silhouette': 0.6081156421364777}, {'rand_score': 0.5471518987341772}, {'calinski': 115.51473598969481})
# agglo ({'mutual_info': 0.12850178115343996}, {'davis_bouldin': 0.5923108059221817}, {'adjusted_rand_score': 0.09941925770140764}, {'silhouette': 0.6081156421364777}, {'rand_score': 0.5471518987341772}, {'calinski': 115.51473598969481})
# ({'mutual_info': 0.12850178115343996}, {'davis_bouldin': 0.5923108059221817}, {'adjusted_rand_score': 0.09941925770140764}, {'silhouette': 0.6081156421364777}, {'rand_score': 0.5471518987341772}, {'calinski': 115.51473598969481})
# birch ({'mutual_info': 0.12850178115343996}, {'davis_bouldin': 0.5923108059221817}, {'adjusted_rand_score': 0.09941925770140764}, {'silhouette': 0.6081156421364777}, {'rand_score': 0.5471518987341772}, {'calinski': 115.51473598969481})
# ({'mutual_info': 0.568046574675398}, {'davis_bouldin': 0.7731581775675409}, {'adjusted_rand_score': 0.307605315238903}, {'silhouette': 0.34095550732285285}, {'rand_score': 0.6566455696202531}, {'calinski': 147.43965713229665})
# affinity ({'mutual_info': 0.568046574675398}, {'davis_bouldin': 0.7731581775675409}, {'adjusted_rand_score': 0.307605315238903}, {'silhouette': 0.34095550732285285}, {'rand_score': 0.6566455696202531}, {'calinski': 147.43965713229665})
# ({'mutual_info': 0.20223272608716186}, {'davis_bouldin': 0.6096026445410114}, {'adjusted_rand_score': 0.21845881141159842}, {'silhouette': 0.6037616135370426}, {'rand_score': 0.6079113924050633}, {'calinski': 133.92501087347864})
# kmeans ({'mutual_info': 0.20223272608716186}, {'davis_bouldin': 0.6096026445410114}, {'adjusted_rand_score': 0.21845881141159842}, {'silhouette': 0.6037616135370426}, {'rand_score': 0.6079113924050633}, {'calinski': 133.92501087347864})
# ({'mutual_info': 0.2297073002884747}, {'davis_bouldin': 0.6205851639092677}, {'adjusted_rand_score': 0.2684542309505357}, {'silhouette': 0.5948616076899353}, {'rand_score': 0.6332278481012659}, {'calinski': 132.77506552890657})
# minbatchkmeans ({'mutual_info': 0.2297073002884747}, {'davis_bouldin': 0.6205851639092677}, {'adjusted_rand_score': 0.2684542309505357}, {'silhouette': 0.5948616076899353}, {'rand_score': 0.6332278481012659}, {'calinski': 132.77506552890657})
# ({'mutual_info': 0.2626714305887388}, {'davis_bouldin': 0.5373009490359753}, {'adjusted_rand_score': 0.3357087317937331}, {'silhouette': 0.5192033472377627}, {'rand_score': 0.6680379746835443}, {'calinski': 127.90534151798371})
# meanshift ({'mutual_info': 0.2626714305887388}, {'davis_bouldin': 0.5373009490359753}, {'adjusted_rand_score': 0.3357087317937331}, {'silhouette': 0.5192033472377627}, {'rand_score': 0.6680379746835443}, {'calinski': 127.90534151798371})
# ({'mutual_info': 0.39710092967003646}, {'davis_bouldin': 0.9526483991143215}, {'adjusted_rand_score': 0.6765330406006362}, {'silhouette': 0.33457729181375484}, {'rand_score': 0.8382911392405064}, {'calinski': 43.94917857951576})
# optics ({'mutual_info': 0.39710092967003646}, {'davis_bouldin': 0.9526483991143215}, {'adjusted_rand_score': 0.6765330406006362}, {'silhouette': 0.33457729181375484}, {'rand_score': 0.8382911392405064}, {'calinski': 43.94917857951576})
# ({'mutual_info': 0.0031495295627013697}, {'davis_bouldin': 6.569133775453518}, {'adjusted_rand_score': -0.005761428834350919}, {'silhouette': 0.054903621395612244}, {'rand_score': 0.49651898734177213}, {'calinski': 1.200562426941988})
# spectral ({'mutual_info': 0.0031495295627013697}, {'davis_bouldin': 6.569133775453518}, {'adjusted_rand_score': -0.005761428834350919}, {'silhouette': 0.054903621395612244}, {'rand_score': 0.49651898734177213}, {'calinski': 1.200562426941988})
# ({'mutual_info': 0.693147180559945}, {'davis_bouldin': 1.0035995580088195}, {'adjusted_rand_score': 1.0}, {'silhouette': 0.3160736063578475}, {'rand_score': 1.0}, {'calinski': 42.01103462747964})
# gaussianmixture ({'mutual_info': 0.693147180559945}, {'davis_bouldin': 1.0035995580088195}, {'adjusted_rand_score': 1.0}, {'silhouette': 0.3160736063578475}, {'rand_score': 1.0}, {'calinski': 42.01103462747964})
